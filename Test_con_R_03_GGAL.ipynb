# %% [markdown]
# <a href="https://colab.research.google.com/github/nitramic/Ansible/blob/main/Test_con_R_03_GGAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Vamos a probar con el ejercicio que estoy haciendo en R-studio ⛹

# %%
install.packages("PerformanceAnalytics")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘xts’, ‘quadprog’, ‘zoo’

# %%
install.packages("rlang")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("quantmod")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘TTR’

# %%
library(quantmod)
# Out:
# Loading required package: xts
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Loading required package: TTR
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %%
library(PerformanceAnalytics)
# Out:
# Attaching package: ‘PerformanceAnalytics’
#
#
# The following object is masked from ‘package:graphics’:
#
#     legend

# %% [markdown]
# Comienzo con la carga de datos desde yahoo finance:
# Tiker Nasdaq ^IXIC
# Año 2021

# %%
mercado = "GGAL"
StartDay ="2022-10-01"
StopDay = "2023-08-25"

# %%
#Cargo los datos en la funcion
valor = getSymbols(mercado,auto.assign = FALSE,from = StartDay, to = StopDay)

# %% [markdown]
# Genero el primer grafico con candleChart

# %%
candleChart(valor)
# Out:
# Plot with title “[2022-10-03/2023-08-24]”

# %%
return = dailyReturn(valor, type = "arithmetic")
charts.PerformanceSummary(return)
# Out:
# Plot with title “daily.returns Performance”

# %%
table.Drawdowns(return)
# Out:
#   From       Trough     To         Depth   Length To Trough Recovery
# 1 2023-01-26 2023-03-20 2023-06-07 -0.2683 92     37        55
# 2 2023-07-24 2023-08-21 <NA>       -0.1580 25     21        NA
# 3 2022-11-02 2022-11-17 2022-12-02 -0.1197 22     12        10
# 4 2022-10-05 2022-10-14 2022-11-01 -0.1128 20      8        12
# 5 2023-01-18 2023-01-18 2023-01-25 -0.0988  6      1         5

# %%
table.CalendarReturns(dailyReturn(to.monthly(valor),type = "arithmetic"))
# Out:
#      Jan  Feb  Mar   Apr May Jun  Jul  Aug  Sep Oct Nov Dec  daily.returns
# 2022   NA   NA    NA  NA NA    NA   NA   NA NA  1.6 4.4 20.1 27.4
# 2023 37.7 -0.6 -17.6 4.9  3  44.9 -1.5 -6.4 NA   NA  NA   NA 63.0
